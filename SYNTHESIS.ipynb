# %% [markdown]
# # Synthetic Greenhouse Gas Emissions Dataset Generation

# %%
library(httr)
library(jsonlite)
library(readr)
library(ggplot2)
library(data.table)
library(utils) 
library(dplyr)
library(tidyr)
library(purrr)
library(zoo) 
library(stringr)
library(stats)
library(tibble)

# %%
# Load the file
data_raw <- read.csv("3A5EGHG1.csv", sep = ";", skip = 1, stringsAsFactors = FALSE, header = TRUE)
# Inspect first few rows
head(data_raw, 10)
# Out:
#    Year Sector.and.Source.Categories                Carbon.Dioxide..CO2.
# 1  2010 ENERGY TOTAL EMISSIONS                      50697.000
# 2  2010 ENERGY TOTAL CO2 EQUIVALENT                 53105.000
# 3  2010 ..Energy Industries                         32803.000
# 4  2010 ..Manufacturing Industries and Construction 11887.000
# 5  2010 ..Other Sectors                             5995.000
# 6  2010 ..Fugitive Emissions - Solid Fuels          ..
# 7  2010 ..Fugitive Emissions - Oil and Natural Gas  12.000
# 8  2010 TRANSPORT TOTAL EMISSIONS                   23718.000
# 9  2010 TRANSPORT TOTAL CO2 EQUIVALENT              24174.000
# 10 2010 ...Domestic Aviation                        706.000
#    Methane..CH4. Nitrous.Oxide..N2O. Hydroflourocarbons..HFCs.
# 1  1887.000      520.000             .
# 2  .             .                   .
# 3  49.000        168.000             .
# 4  55.000        95.000              .
# 5  1692.000      257.000             .
# 6  90.000        ..                  .
# 7  1.000         0.000               .
# 8  125.000       331.000             .
# 9  .             .                   .
# 10 0.000         6.000               .

# %%
# Rename columns to simplified versions
colnames(data_raw) <- c("Year", "Sector", "CO2", "CH4", "N2O", "HFCs")

# Replace '.' and '..' with NA
data_raw[data_raw == "." | data_raw == ".."] <- NA


# Preview the data
tail(data_raw, 5)
# Out:
#     Year Sector                                   CO2        CH4       N2O
# 134 2020 ..Solid Waste Disposal                   NA         11689.692 NA
# 135 2020 ..Biological Treatment of Solid Waste    NA         391.664   222.335
# 136 2020 ..Incineration and Open Burning of Waste 0.322      1.288     0.265
# 137 2020 ..Wastewater Treatment and Discharge     NA         16563.680 1253.185
# 138 2020 TOTAL NATIONAL GHG EMISSIONS (CO2-e)     204325.244 NA        NA
#     HFCs
# 134 NA
# 135 NA
# 136 NA
# 137 NA
# 138 NA

# %%
# Convert CO2, CH4, N2O, and HFCs columns to numeric
data_raw$CO2 <- as.numeric(data_raw$CO2)
data_raw$CH4 <- as.numeric(data_raw$CH4)
data_raw$N2O <- as.numeric(data_raw$N2O)
data_raw$HFCs <- as.numeric(data_raw$HFCs)

# %%
# Remove leading ".." or "..." from Sector names
data_raw$Sector <- gsub("^\\.+", "", data_raw$Sector)

# Trim leading/trailing whitespace
data_raw$Sector <- trimws(data_raw$Sector)

# %%
# View cleaned sample
# head(data_raw, 10)
data_raw
# Out:
#     Year Sector                                                     CO2
# 1   2010 ENERGY TOTAL EMISSIONS                                      50697
# 2   2010 ENERGY TOTAL CO2 EQUIVALENT                                 53105
# 3   2010 Energy Industries                                           32803
# 4   2010 Manufacturing Industries and Construction                   11887
# 5   2010 Other Sectors                                                5995
# 6   2010 Fugitive Emissions - Solid Fuels                               NA
# 7   2010 Fugitive Emissions - Oil and Natural Gas                       12
# 8   2010 TRANSPORT TOTAL EMISSIONS                                   23718
# 9   2010 TRANSPORT TOTAL CO2 EQUIVALENT                              24174
# 10  2010 Domestic Aviation                                             706
# 11  2010 Road Transport                                              20816
# 12  2010 Railways                                                       NA
# 13  2010 Water-borne Navigation                                       2196
# 14  2010 Other Transportation                                           NA
# 15  2010 AGRICULTURE TOTAL EMISSIONS                                   696
# 16  2010 AGRICULTURE TOTAL CO2 EQUIVALENT                            43152
# 17  2010 Rice Cultivation                                               NA
# 18  2010 Enteric Fermentation                                           NA
# 19  2010 Manure Management                                              NA
# 20  2010 Direct N2O Emissions from Managed Soils                        NA
# 21  2010 Indirect N2O Emissions from Managed Soils                      NA
# 22  2010 Direct N2O Emissions from Manure Management                    NA
# 23  2010 Biomass Burning in Croplands and Grasslands                    NA
# 24  2010 Liming                                                          2
# 25  2010 Urea Application                                              694
# 26  2010 FORESTRY AND OTHER LAND USE TOTAL EMISSIONS                -37016
# 27  2010 FORESTRY AND OTHER LAND USE TOTAL CO2 EQUIVALENT           -37007
# 28  2010 Biomass Carbon Stock Silvopasture                          -51252
# 29  2010 Biomass Carbon Stock                                        11084
# 30  2010 Biomass Carbon Stock Deforestation                          16125
# ⋮   ⋮    ⋮                                                          ⋮
# 109 2020 Rice Cultivation                                                   NA
# 110 2020 Enteric Fermentation                                               NA
# 111 2020 Manure Management                                                  NA
# 112 2020 Direct N2O Emissions from Managed Soils                            NA
# 113 2020 Indirect N2O Emissions from Managed Soils                          NA
# 114 2020 Direct N2O Emissions from Manure Management                        NA
# 115 2020 Biomass Burning in Croplands and Grasslands                        NA
# 116 2020 Liming                                                        127.820
# 117 2020 Urea Application                                              637.263
# 118 2020 FORESTRY AND OTHER LAND USE TOTAL EMISSIONS                -25935.063
# 119 2020 FORESTRY AND OTHER LAND USE TOTAL CO2 EQUIVALENT           -25935.063
# 120 2020 Biomass Carbon Stock Silvopasture                          -71354.677
# 121 2020 Biomass Carbon Stock                                        11247.006
# 122 2020 Biomass Carbon Stock Deforestation                          31302.244
# 123 2020 Biomass Carbon Stock Agroforestry/Perennial Crop             2125.769
# 124 2020 Biomass Burning - Forests                                     744.594
# 125 2020 INDUSTRIAL PROCESSES AND PRODUCT USE TOTAL EMISSIONS        13666.388
# 126 2020 INDUSTRIAL PROCESS AND PRODUCT USE TOTAL CO2 EQUIVALENT     16772.292
# 127 2020 Mineral Industry                                            11779.664
# 128 2020 Chemical Industry                                             559.974
# 129 2020 Metal Industry                                               1280.711
# 130 2020 Non-Energy Products from Fuels and Solvent Use                 46.039
# 131 2020 Product Uses as Substitutes for Ozone-Depleting Substances         NA
# 132 2020 WASTES TOTAL EMISSIONS                                          0.322
# 133 2020 WASTES TOTAL CO2 EQUIVALENT                                 30122.431
# 134 2020 Solid Waste Disposal                                               NA
# 135 2020 Biological Treatment of Solid Waste                                NA
# 136 2020 Incineration and Open Burning of Waste                          0.322
# 137 2020 Wastewater Treatment and Discharge                                 NA
# 138 2020 TOTAL NATIONAL GHG EMISSIONS (CO2-e)                       204325.244
#     CH4       N2O      HFCs
# 1    1887      520     NA
# 2      NA       NA     NA
# 3      49      168     NA
# 4      55       95     NA
# 5    1692      257     NA
# 6      90       NA     NA
# 7       1        0     NA
# 8     125      331     NA
# 9      NA       NA     NA
# 10      0        6     NA
# 11    120      308     NA
# 12     NA       NA     NA
# 13      5       17     NA
# 14     NA       NA     NA
# 15  33852     8603     NA
# 16     NA       NA     NA
# 17  22377       NA     NA
# 18   8490       NA     NA
# 19   2699     1082     NA
# 20     NA     5694     NA
# 21     NA     1311     NA
# 22     NA      420     NA
# 23    286       96     NA
# 24     NA       NA     NA
# 25     NA       NA     NA
# 26      7        2     NA
# 27     NA       NA     NA
# 28     NA       NA     NA
# 29     NA       NA     NA
# 30     NA       NA     NA
# ⋮   ⋮         ⋮        ⋮
# 109 26984.898       NA       NA
# 110  8327.213       NA       NA
# 111  2751.749 4406.452       NA
# 112        NA 6875.216       NA
# 113        NA 2277.200       NA
# 114        NA 1220.157       NA
# 115   370.367  101.662       NA
# 116        NA       NA       NA
# 117        NA       NA       NA
# 118        NA       NA       NA
# 119        NA       NA       NA
# 120        NA       NA       NA
# 121        NA       NA       NA
# 122        NA       NA       NA
# 123        NA       NA       NA
# 124        NA       NA       NA
# 125    27.705       NA 3078.199
# 126        NA       NA       NA
# 127        NA       NA       NA
# 128    20.915       NA       NA
# 129     6.790       NA       NA
# 130        NA       NA       NA
# 131        NA       NA 3078.199
# 132 28646.324 1475.785       NA
# 133        NA       NA       NA
# 134 11689.692       NA       NA
# 135   391.664  222.335       NA
# 136     1.288    0.265       NA
# 137 16563.680 1253.185       NA
# 138        NA       NA       NA

# %%
summary(data_raw)
# Out:
#       Year         Sector               CO2                CH4
#  Min.   :2010   Length:138         Min.   :-71354.7   Min.   :    0.0
#  1st Qu.:2010   Class :character   1st Qu.:   127.8   1st Qu.:    9.0
#  Median :2015   Mode  :character   Median :  6477.0   Median :  112.2
#  Mean   :2015                      Mean   : 17636.3   Mean   : 5017.9
#  3rd Qu.:2020                      3rd Qu.: 28895.8   3rd Qu.: 3000.8
#  Max.   :2020                      Max.   :232987.6   Max.   :38434.2
#                                    NA's   :41         NA's   :65
#       N2O               HFCs
#  Min.   :    0.0   Min.   : 771
#  1st Qu.:   18.7   1st Qu.:1137
#  Median :  272.8   Median :2234
#  Mean   : 1397.4   Mean   :2028
#  3rd Qu.: 1071.3   3rd Qu.:2867
#  Max.   :14880.7   Max.   :3078
#  NA's   :74        NA's   :132

# %%
# Unique sectors
unique_sectors <- unique(data_raw$Sector)
length(unique_sectors)  # Number of sectors
unique_sectors
# Out:
# [1] 46
#  [1] "ENERGY TOTAL EMISSIONS"
#  [2] "ENERGY TOTAL CO2 EQUIVALENT"
#  [3] "Energy Industries"
#  [4] "Manufacturing Industries and Construction"
#  [5] "Other Sectors"
#  [6] "Fugitive Emissions - Solid Fuels"
#  [7] "Fugitive Emissions - Oil and Natural Gas"
#  [8] "TRANSPORT TOTAL EMISSIONS"
#  [9] "TRANSPORT TOTAL CO2 EQUIVALENT"
# [10] "Domestic Aviation"
# [11] "Road Transport"
# [12] "Railways"
# [13] "Water-borne Navigation"
# [14] "Other Transportation"
# [15] "AGRICULTURE TOTAL EMISSIONS"
# [16] "AGRICULTURE TOTAL CO2 EQUIVALENT"
# [17] "Rice Cultivation"
# [18] "Enteric Fermentation"
# [19] "Manure Management"
# [20] "Direct N2O Emissions from Managed Soils"
# [21] "Indirect N2O Emissions from Managed Soils"
# [22] "Direct N2O Emissions from Manure Management"
# [23] "Biomass Burning in Croplands and Grasslands"
# [24] "Liming"
# [25] "Urea Application"
# [26] "FORESTRY AND OTHER LAND USE TOTAL EMISSIONS"
# [27] "FORESTRY AND OTHER LAND USE TOTAL CO2 EQUIVALENT"
# [28] "Biomass Carbon Stock Silvopasture"
# [29] "Biomass Carbon Stock"
# [30] "Biomass Carbon Stock Deforestation"
# [31] "Biomass Carbon Stock Agroforestry/Perennial Crop"
# [32] "Biomass Burning - Forests"
# [33] "INDUSTRIAL PROCESSES AND PRODUCT USE TOTAL EMISSIONS"
# [34] "INDUSTRIAL PROCESS AND PRODUCT USE TOTAL CO2 EQUIVALENT"
# [35] "Mineral Industry"
# [36] "Chemical Industry"
# [37] "Metal Industry"
# [38] "Non-Energy Products from Fuels and Solvent Use"
# [39] "Product Uses as Substitutes for Ozone-Depleting Substances"
# [40] "WASTES TOTAL EMISSIONS"
# [41] "WASTES TOTAL CO2 EQUIVALENT"
# [42] "Solid Waste Disposal"
# [43] "Biological Treatment of Solid Waste"
# [44] "Incineration and Open Burning of Waste"
# [45] "Wastewater Treatment and Discharge"
# [46] "TOTAL NATIONAL GHG EMISSIONS (CO2-e)"

# %%
# --- Step 2: Plot CO2 emissions time series for selected sectors ---

# Step 1: Keep original 2010–2020 data with at least one gas value present
data_clean <- data_raw %>%
  filter(!is.na(CO2) | !is.na(CH4) | !is.na(N2O) | !is.na(HFCs))

# Unique sectors, gases, and future years
sectors <- unique(data_clean$Sector)
gases <- c("CO2", "CH4", "N2O", "HFCs")
years_future <- 2021:2050

# Function to impute missing values via linear interpolation in historical data
impute_linear <- function(df) {
  # Ensure data is sorted by Year
  df <- df %>% arrange(Year)
  # Apply na.approx interpolation; if leading/trailing NAs, keep them as NA
  df$Value <- na.approx(df$Value, x = df$Year, na.rm = FALSE)
  return(df)
}

# Function to simulate emissions per sector-gas with imputation and regression forecasting
simulate_emissions <- function(sector, gas) {
  # Extract historical data for sector-gas
  df_sector <- data_clean %>%
    filter(Sector == sector) %>%
    select(Year, Value = all_of(gas))
  
  # Impute missing values in historical data using linear interpolation
  df_imputed <- impute_linear(df_sector)
  
  # Filter out any remaining NAs after interpolation (e.g., leading/trailing)
  df_model <- df_imputed %>% filter(!is.na(Value))
  
  if (nrow(df_model) >= 3) {
    # Fit linear regression model on imputed data
    model <- lm(Value ~ Year, data = df_model)
    # Predict future values for 2021-2050
    future_values <- predict(model, newdata = data.frame(Year = years_future))
  } else if (nrow(df_model) > 0) {
    # Not enough points for regression: repeat last known value
    future_values <- rep(tail(df_model$Value, 1), length(years_future))
  } else {
    # No data at all: fill with NA to reflect missingness
    future_values <- rep(NA_real_, length(years_future))
  }
  
  # Return synthetic future data in long format
  data.frame(
    Year = years_future,
    Sector = sector,
    Gas = gas,
    Value = future_values
  )
}

# Step 2: Generate synthetic future data for all sector-gas combinations
synthetic_data_long <- expand_grid(Sector = sectors, Gas = gases) %>%
  pmap_dfr(~simulate_emissions(..1, ..2))

# Step 3: Pivot synthetic data to wide format (Year, Sector, CO2, CH4, N2O, HFCs)
synthetic_data <- synthetic_data_long %>%
  pivot_wider(names_from = Gas, values_from = Value) %>%
  arrange(Year, Sector)

# Step 4: Prepare original real data (keep original NAs, no imputation here)
real_data <- data_clean %>%
  select(Year, Sector, all_of(gases)) %>%
  arrange(Year, Sector)

# Step 5: Combine real historical and synthetic future data
combined_data <- bind_rows(real_data, synthetic_data) %>%
  arrange(Sector, Year)

# Optional: Trim whitespace in Sector names
combined_data$Sector <- stringr::str_trim(combined_data$Sector)

# Step 6: Save combined dataset to CSV
write_csv(combined_data, "phil_synthetic_ghg_emissions_2010_2050.csv")

# Summary message
cat("Saved combined dataset with imputed historical data and synthetic forecasts from 2010 to 2050.\n")
# Out:
# Saved combined dataset with imputed historical data and synthetic forecasts from 2010 to 2050.

# %%
combined_data
# Out:
#      Year Sector                           CO2      CH4     N2O      HFCs
# 1    2010 AGRICULTURE TOTAL CO2 EQUIVALENT 43152.00 NA      NA       NA
# 2    2015 AGRICULTURE TOTAL CO2 EQUIVALENT 52703.55 NA      NA       NA
# 3    2020 AGRICULTURE TOTAL CO2 EQUIVALENT 54080.00 NA      NA       NA
# 4    2021 AGRICULTURE TOTAL CO2 EQUIVALENT 56535.31 NA      NA       NA
# 5    2022 AGRICULTURE TOTAL CO2 EQUIVALENT 57628.11 NA      NA       NA
# 6    2023 AGRICULTURE TOTAL CO2 EQUIVALENT 58720.91 NA      NA       NA
# 7    2024 AGRICULTURE TOTAL CO2 EQUIVALENT 59813.71 NA      NA       NA
# 8    2025 AGRICULTURE TOTAL CO2 EQUIVALENT 60906.51 NA      NA       NA
# 9    2026 AGRICULTURE TOTAL CO2 EQUIVALENT 61999.31 NA      NA       NA
# 10   2027 AGRICULTURE TOTAL CO2 EQUIVALENT 63092.11 NA      NA       NA
# 11   2028 AGRICULTURE TOTAL CO2 EQUIVALENT 64184.91 NA      NA       NA
# 12   2029 AGRICULTURE TOTAL CO2 EQUIVALENT 65277.71 NA      NA       NA
# 13   2030 AGRICULTURE TOTAL CO2 EQUIVALENT 66370.51 NA      NA       NA
# 14   2031 AGRICULTURE TOTAL CO2 EQUIVALENT 67463.31 NA      NA       NA
# 15   2032 AGRICULTURE TOTAL CO2 EQUIVALENT 68556.11 NA      NA       NA
# 16   2033 AGRICULTURE TOTAL CO2 EQUIVALENT 69648.91 NA      NA       NA
# 17   2034 AGRICULTURE TOTAL CO2 EQUIVALENT 70741.71 NA      NA       NA
# 18   2035 AGRICULTURE TOTAL CO2 EQUIVALENT 71834.51 NA      NA       NA
# 19   2036 AGRICULTURE TOTAL CO2 EQUIVALENT 72927.31 NA      NA       NA
# 20   2037 AGRICULTURE TOTAL CO2 EQUIVALENT 74020.11 NA      NA       NA
# 21   2038 AGRICULTURE TOTAL CO2 EQUIVALENT 75112.91 NA      NA       NA
# 22   2039 AGRICULTURE TOTAL CO2 EQUIVALENT 76205.71 NA      NA       NA
# 23   2040 AGRICULTURE TOTAL CO2 EQUIVALENT 77298.51 NA      NA       NA
# 24   2041 AGRICULTURE TOTAL CO2 EQUIVALENT 78391.31 NA      NA       NA
# 25   2042 AGRICULTURE TOTAL CO2 EQUIVALENT 79484.11 NA      NA       NA
# 26   2043 AGRICULTURE TOTAL CO2 EQUIVALENT 80576.91 NA      NA       NA
# 27   2044 AGRICULTURE TOTAL CO2 EQUIVALENT 81669.71 NA      NA       NA
# 28   2045 AGRICULTURE TOTAL CO2 EQUIVALENT 82762.51 NA      NA       NA
# 29   2046 AGRICULTURE TOTAL CO2 EQUIVALENT 83855.31 NA      NA       NA
# 30   2047 AGRICULTURE TOTAL CO2 EQUIVALENT 84948.11 NA      NA       NA
# ⋮    ⋮    ⋮                                ⋮        ⋮       ⋮        ⋮
# 1486 2021 Water-borne Navigation           2643.686  7.2360 18.63967 NA
# 1487 2022 Water-borne Navigation           2657.791  7.3565 18.61767 NA
# 1488 2023 Water-borne Navigation           2671.896  7.4770 18.59567 NA
# 1489 2024 Water-borne Navigation           2686.001  7.5975 18.57367 NA
# 1490 2025 Water-borne Navigation           2700.106  7.7180 18.55167 NA
# 1491 2026 Water-borne Navigation           2714.211  7.8385 18.52967 NA
# 1492 2027 Water-borne Navigation           2728.316  7.9590 18.50767 NA
# 1493 2028 Water-borne Navigation           2742.421  8.0795 18.48567 NA
# 1494 2029 Water-borne Navigation           2756.526  8.2000 18.46367 NA
# 1495 2030 Water-borne Navigation           2770.631  8.3205 18.44167 NA
# 1496 2031 Water-borne Navigation           2784.737  8.4410 18.41967 NA
# 1497 2032 Water-borne Navigation           2798.842  8.5615 18.39767 NA
# 1498 2033 Water-borne Navigation           2812.947  8.6820 18.37567 NA
# 1499 2034 Water-borne Navigation           2827.052  8.8025 18.35367 NA
# 1500 2035 Water-borne Navigation           2841.157  8.9230 18.33167 NA
# 1501 2036 Water-borne Navigation           2855.262  9.0435 18.30967 NA
# 1502 2037 Water-borne Navigation           2869.367  9.1640 18.28767 NA
# 1503 2038 Water-borne Navigation           2883.472  9.2845 18.26567 NA
# 1504 2039 Water-borne Navigation           2897.577  9.4050 18.24367 NA
# 1505 2040 Water-borne Navigation           2911.682  9.5255 18.22167 NA
# 1506 2041 Water-borne Navigation           2925.788  9.6460 18.19967 NA
# 1507 2042 Water-borne Navigation           2939.893  9.7665 18.17767 NA
# 1508 2043 Water-borne Navigation           2953.998  9.8870 18.15567 NA
# 1509 2044 Water-borne Navigation           2968.103 10.0075 18.13367 NA
# 1510 2045 Water-borne Navigation           2982.208 10.1280 18.11167 NA
# 1511 2046 Water-borne Navigation           2996.313 10.2485 18.08967 NA
# 1512 2047 Water-borne Navigation           3010.418 10.3690 18.06767 NA
# 1513 2048 Water-borne Navigation           3024.523 10.4895 18.04567 NA
# 1514 2049 Water-borne Navigation           3038.628 10.6100 18.02367 NA
# 1515 2050 Water-borne Navigation           3052.733 10.7305 18.00167 NA

# %%
# --- Step 2: Plot CO2 emissions time series for selected sectors ---

sectors_to_plot <- c("ENERGY TOTAL EMISSIONS", "TRANSPORT TOTAL EMISSIONS", "AGRICULTURE TOTAL EMISSIONS")

plot_data <- combined_data %>%
  filter(Sector %in% sectors_to_plot) %>%
  mutate(Sector = str_to_title(Sector))

ggplot(plot_data, aes(x = Year, y = CO2, color = Sector)) +
  geom_line(linewidth = 1) +
  geom_point(size = 1.5, alpha = 0.7) +
  labs(title = "CO2 Emissions by Sector (2010–2050)",
       x = "Year",
       y = "CO2 Emissions",
       color = "Sector") +
  theme_minimal() +
  theme(legend.position = "bottom")
# Out:
# plot without title

# %%
# --- Step 3: PCA visualization without ggfortify ---

# Prepare data for PCA: sectors as rows, years as columns, CO2 emissions only
pca_data <- combined_data %>%
  select(Year, Sector, CO2) %>%
  pivot_wider(names_from = Year, values_from = CO2) %>%
  column_to_rownames("Sector")

# Replace NAs with zeros (or consider other imputation if preferred)
pca_data[is.na(pca_data)] <- 0

# Perform PCA
pca_result <- prcomp(pca_data, scale. = TRUE)

# Extract first two principal components
pca_scores <- as.data.frame(pca_result$x[, 1:2])
pca_scores$Sector <- rownames(pca_scores)

# Plot PCA with ggplot2
ggplot(pca_scores, aes(x = PC1, y = PC2, label = Sector)) +
  geom_point(color = "blue", size = 3) +
  geom_text(vjust = -0.5, hjust = 0.5, size = 3) +
  labs(title = "PCA of Sectors Based on CO2 Emission Profiles (2010–2050)",
       x = paste0("PC1 (", round(summary(pca_result)$importance[2,1]*100, 1), "% variance)"),
       y = paste0("PC2 (", round(summary(pca_result)$importance[2,2]*100, 1), "% variance)")) +
  theme_minimal()
# Out:
# plot without title

# %%
set.seed(123)
k <- 3  # number of clusters
clusters <- kmeans(pca_scores[, c("PC1", "PC2")], centers = k, nstart = 25)
pca_scores$Cluster <- factor(clusters$cluster)

ggplot(pca_scores, aes(x = PC1, y = PC2, color = Cluster, label = Sector)) +
  geom_point(size = 4) +
  geom_text(vjust = -0.5, hjust = 0.5, size = 3) +
  labs(title = "Sector Clusters Based on PCA of CO2 Emissions",
       color = "Cluster") +
  theme_minimal()
# Out:
# plot without title
